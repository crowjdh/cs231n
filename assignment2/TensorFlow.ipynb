# %% [markdown]
# ## What's this TensorFlow business?
#
# You've written a lot of code in this assignment to provide a whole host of neural network functionality. Dropout, Batch Norm, and 2D convolutions are some of the workhorses of deep learning in computer vision. You've also worked hard to make your code efficient and vectorized.
#
# For the last part of this assignment, though, we're going to leave behind your beautiful codebase and instead migrate to one of two popular deep learning frameworks: in this instance, TensorFlow (or PyTorch, if you switch over to that notebook)
#
# #### What is it?
# TensorFlow is a system for executing computational graphs over Tensor objects, with native support for performing backpropogation for its Variables. In it, we work with Tensors which are n-dimensional arrays analogous to the numpy ndarray.
#
# #### Why?
#
# * Our code will now run on GPUs! Much faster training. Writing your own modules to run on GPUs is beyond the scope of this class, unfortunately.
# * We want you to be ready to use one of these frameworks for your project so you can experiment more efficiently than if you were writing every feature you want to use by hand.
# * We want you to stand on the shoulders of giants! TensorFlow and PyTorch are both excellent frameworks that will make your lives a lot easier, and now that you understand their guts, you are free to use them :)
# * We want you to be exposed to the sort of deep learning code you might run into in academia or industry.

# %% [markdown]
# ## How will I learn TensorFlow?
#
# TensorFlow has many excellent tutorials available, including those from [Google themselves](https://www.tensorflow.org/get_started/get_started).
#
# Otherwise, this notebook will walk you through much of what you need to do to train models in TensorFlow. See the end of the notebook for some links to helpful tutorials if you want to learn more or need further clarification on topics that aren't fully explained here.

# %% [markdown]
# ## Load Datasets

# %%
import tensorflow as tf
import numpy as np
import math
import timeit
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /Users/jeong/Dev/python/projects/cs231/assignments/assignment2/.env/lib/python2.7/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=10000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)

    # Subsample the data
    mask = range(num_training, num_training + num_validation)
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = range(num_training)
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = range(num_test)
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# ('Train data shape: ', (49000, 32, 32, 3))
# ('Train labels shape: ', (49000,))
# ('Validation data shape: ', (1000, 32, 32, 3))
# ('Validation labels shape: ', (1000,))
# ('Test data shape: ', (10000, 32, 32, 3))
# ('Test labels shape: ', (10000,))

# %% [markdown]
# ## Example Model
#
# ### Some useful utilities
#
# . Remember that our image data is initially N x H x W x C, where:
# * N is the number of datapoints
# * H is the height of each image in pixels
# * W is the height of each image in pixels
# * C is the number of channels (usually 3: R, G, B)
#
# This is the right way to represent the data when we are doing something like a 2D convolution, which needs spatial understanding of where the pixels are relative to each other. When we input image data into fully connected affine layers, however, we want each data example to be represented by a single vector -- it's no longer useful to segregate the different channels, rows, and columns of the data.

# %% [markdown]
# ### The example model itself
#
# The first step to training your own model is defining its architecture.
#
# Here's an example of a convolutional neural network defined in TensorFlow -- try to understand what each line is doing, remembering that each layer is composed upon the previous layer. We haven't trained anything yet - that'll come next - for now, we want you to understand how everything gets set up.
#
# In that example, you see 2D convolutional layers (Conv2d), ReLU activations, and fully-connected layers (Linear). You also see the Hinge loss function, and the Adam optimizer being used.
#
# Make sure you understand why the parameters of the Linear layer are 5408 and 10.
#
# ### TensorFlow Details
# In TensorFlow, much like in our previous notebooks, we'll first specifically initialize our variables, and then our network model.

# %%
# clear old variables
tf.reset_default_graph()

# setup input (e.g. the data that changes every batch)
# The first dim is None, and gets sets automatically based on batch size fed in
X = tf.placeholder(tf.float32, [None, 32, 32, 3])
y = tf.placeholder(tf.int64, [None])
is_training = tf.placeholder(tf.bool)

def simple_model(X,y):
    # define our weights (e.g. init_two_layer_convnet)
    
    # setup variables
    Wconv1 = tf.get_variable("Wconv1", shape=[7, 7, 3, 32])
    bconv1 = tf.get_variable("bconv1", shape=[32])
    W1 = tf.get_variable("W1", shape=[5408, 10])
    b1 = tf.get_variable("b1", shape=[10])

    # define our graph (e.g. two_layer_convnet)
    a1 = tf.nn.conv2d(X, Wconv1, strides=[1,2,2,1], padding='VALID') + bconv1
    h1 = tf.nn.relu(a1)
    h1_flat = tf.reshape(h1,[-1,5408])
    y_out = tf.matmul(h1_flat,W1) + b1
    return y_out

y_out = simple_model(X,y)

# define our loss
total_loss = tf.losses.hinge_loss(tf.one_hot(y,10),logits=y_out)
mean_loss = tf.reduce_mean(total_loss)

# define our optimizer
optimizer = tf.train.AdamOptimizer(5e-4) # select optimizer and set learning rate
train_step = optimizer.minimize(mean_loss)

# %% [markdown]
# TensorFlow supports many other layer types, loss functions, and optimizers - you will experiment with these next. Here's the official API documentation for these (if any of the parameters used above were unclear, this resource will also be helpful).
#
# * Layers, Activations, Loss functions : https://www.tensorflow.org/api_guides/python/nn
# * Optimizers: https://www.tensorflow.org/api_guides/python/train#Optimizers
# * BatchNorm: https://www.tensorflow.org/api_docs/python/tf/layers/batch_normalization

# %% [markdown]
# ### Training the model on one epoch
# While we have defined a graph of operations above, in order to execute TensorFlow Graphs, by feeding them input data and computing the results, we first need to create a `tf.Session` object. A session encapsulates the control and state of the TensorFlow runtime. For more information, see the TensorFlow [Getting started](https://www.tensorflow.org/get_started/get_started) guide.
#
# Optionally we can also specify a device context such as `/cpu:0` or `/gpu:0`. For documentation on this behavior see [this TensorFlow guide](https://www.tensorflow.org/tutorials/using_gpu)
#
# You should see a validation loss of around 0.4 to 0.6 and an accuracy of 0.30 to 0.35 below

# %%
print(y.graph)

# %%
def run_model(session, predict, loss_val, X, y, is_training, Xd, yd,
              epochs=1, batch_size=64, print_every=100,
              training=None, plot_losses=False, graph=tf.get_default_graph()):
    # have tensorflow compute accuracy
    with graph.as_default():
        correct_prediction = tf.equal(tf.argmax(predict,1), y)
        accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    
    # shuffle indicies
    train_indicies = np.arange(Xd.shape[0])
    np.random.shuffle(train_indicies)

    training_now = training is not None
    
    # setting up variables we want to compute (and optimizing)
    # if we have a training function, add that to things we compute
    variables = [loss_val,correct_prediction,accuracy]
    if training_now:
        variables[-1] = training
    
    # counter 
    iter_cnt = 0
    for e in range(epochs):
        # keep track of losses and accuracy
        correct = 0
        losses = []
        # make sure we iterate over the dataset once
        for i in range(int(math.ceil(Xd.shape[0]/batch_size))):
            # generate indicies for the batch
            start_idx = (i*batch_size)%Xd.shape[0]
            idx = train_indicies[start_idx:start_idx+batch_size]
            
            # create a feed dictionary for this batch
            feed_dict = {X: Xd[idx,:],
                         y: yd[idx],
                         is_training: training_now }
            # get batch size
            actual_batch_size = yd[idx].shape[0]
            
            # have tensorflow compute loss and correct predictions
            # and (if given) perform a training step
            loss, corr, _ = session.run(variables,feed_dict=feed_dict)
            
            # aggregate performance stats
            losses.append(loss*actual_batch_size)
            correct += np.sum(corr)
            
            # print every now and then
            if training_now and (iter_cnt % print_every) == 0:
                print("Iteration {0}: with minibatch training loss = {1:.3g} and accuracy of {2:.2g}"\
                      .format(iter_cnt,loss,float(np.sum(corr))/float(actual_batch_size)))
            iter_cnt += 1
        total_correct = float(correct)/float(Xd.shape[0])
        total_loss = np.sum(losses)/Xd.shape[0]
        print("Epoch {2}, Overall loss = {0:.3g} and accuracy of {1:.3g}"\
              .format(total_loss,total_correct,e+1))
        if plot_losses:
            plt.plot(losses)
            plt.grid(True)
            plt.title('Epoch {} Loss'.format(e+1))
            plt.xlabel('minibatch number')
            plt.ylabel('minibatch loss')
            plt.show()
    return total_loss,total_correct

with tf.Session() as sess:
    with tf.device("/cpu:0"): #"/cpu:0" or "/gpu:0" 
        sess.run(tf.global_variables_initializer())
        print('Training')
        run_model(sess,y_out,mean_loss,X,y,is_training,X_train,y_train,1,64,100,train_step,True)
        print('Validation')
        run_model(sess,y_out,mean_loss,X,y,is_training,X_val,y_val,1,64)
# Out:
# Training
# Iteration 0: with minibatch training loss = 15.2 and accuracy of 0
# Iteration 100: with minibatch training loss = 0.991 and accuracy of 0.31
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-59e3afc12a77> in <module>()
#      66         sess.run(tf.global_variables_initializer())
#      67         print('Training')
# ---> 68         run_model(sess,y_out,mean_loss,X,y,is_training,X_train,y_train,1,64,100,train_step,True)
#      69         print('Validation')
#      70         run_model(sess,y_out,mean_loss,X,y,is_training,X_val,y_val,1,64)
#
# <ipython-input-58-59e3afc12a77> in run_model(session, predict, loss_val, X, y, is_training, Xd, yd, epochs, batch_size, print_every, training, plot_losses, graph)
#      40             # have tensorflow compute loss and correct predictions
#      41             # and (if given) perform a training step
# ---> 42             loss, corr, _ = session.run(variables,feed_dict=feed_dict)
#      43
#      44             # aggregate performance stats
#
# /Users/jeong/Dev/python/projects/cs231/assignments/assignment2/.env/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/jeong/Dev/python/projects/cs231/assignments/assignment2/.env/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1102             feed_handles[subfeed_t] = subfeed_val
#    1103           else:
# -> 1104             np_val = np.asarray(subfeed_val, dtype=subfeed_dtype)
#    1105
#    1106           if (not is_tensor_handle_feed and
#
# /Users/jeong/Dev/python/projects/cs231/assignments/assignment2/.env/lib/python2.7/site-packages/numpy/core/numeric.pyc in asarray(a, dtype, order)
#     490
#     491     """
# --> 492     return array(a, dtype, copy=False, order=order)
#     493
#     494
#
# KeyboardInterrupt:

# %% [markdown]
# ## Training a specific model
#
# In this section, we're going to specify a model for you to construct. The goal here isn't to get good performance (that'll be next), but instead to get comfortable with understanding the TensorFlow documentation and configuring your own model.
#
# Using the code provided above as guidance, and using the following TensorFlow documentation, specify a model with the following architecture:
#
# * 7x7 Convolutional Layer with 32 filters and stride of 1
# * ReLU Activation Layer
# * Spatial Batch Normalization Layer (trainable parameters, with scale and centering)
# * 2x2 Max Pooling layer with a stride of 2
# * Affine layer with 1024 output units
# * ReLU Activation Layer
# * Affine layer from 1024 input units to 10 outputs

# %%
# clear old variables
tf.reset_default_graph()

# define our input (e.g. the data that changes every batch)
# The first dim is None, and gets sets automatically based on batch size fed in
X = tf.placeholder(tf.float32, [None, 32, 32, 3])
y = tf.placeholder(tf.int64, [None])
is_training = tf.placeholder(tf.bool)

# define model
def complex_model(X,y,is_training):
    W_conv_1 = tf.get_variable("W_conv_1", [7, 7, 3, 32])
    b_conv_1 = tf.get_variable("b_conv_1", [32])
    W_fc_1 = tf.get_variable('W_fc_1', [5408, 1024])
    b_fc_1 = tf.get_variable('b_fc_1', [1024])
    W_fc_2 = tf.get_variable('W_fc_2', [1024, 10])
    b_fc_2 = tf.get_variable('b_fc_2', [10])
    
    # (in - filter + 1) / stride
    # (32 - 7 + 1) / 1 = 26 => [None, 26, 26, 32]
    out_conv_1 = tf.nn.conv2d(X, W_conv_1, strides=[1, 1, 1, 1], padding='VALID') + b_conv_1
    out_relu_1 = tf.nn.relu(out_conv_1)
    
    out_bn_1 = tf.layers.batch_normalization(out_relu_1, training=is_training)
    # [None, 13, 13, 32]
    out_mp_1 = tf.nn.max_pool(out_bn_1, [1, 2, 2, 1], [1, 2, 2, 1], 'VALID')
    out_mp_1_reshaped = tf.reshape(out_mp_1, [-1, 5408])
    
    out_fc_1 = tf.matmul(out_mp_1_reshaped, W_fc_1) + b_fc_1
    out_relu_2 = tf.nn.relu(out_fc_1)
    
    out_fc_2 = tf.matmul(out_relu_2, W_fc_2) + b_fc_2
    
    return out_fc_2

y_out = complex_model(X,y,is_training)

# %% [markdown]
# To make sure you're doing the right thing, use the following tool to check the dimensionality of your output (it should be 64 x 10, since our batches have size 64 and the output of the final affine layer should be 10, corresponding to our 10 classes):

# %%
# Now we're going to feed a random batch into the model 
# and make sure the output is the right size
x = np.random.randn(64, 32, 32,3)
with tf.Session() as sess:
    with tf.device("/cpu:0"): #"/cpu:0" or "/gpu:0"
        tf.global_variables_initializer().run()

        ans = sess.run(y_out,feed_dict={X:x,is_training:True})
        # %timeit sess.run(y_out,feed_dict={X:x,is_training:True})
        print(ans.shape)
        print(np.array_equal(ans.shape, np.array([64, 10])))

# %% [markdown]
# You should see the following from the run above
#
# `(64, 10)`
#
# `True`

# %% [markdown]
# ### GPU!
#
# Now, we're going to try and start the model under the GPU device, the rest of the code stays unchanged and all our variables and operations will be computed using accelerated code paths. However, if there is no GPU, we get a Python exception and have to rebuild our graph. On a dual-core CPU, you might see around 50-80ms/batch running the above, while the Google Cloud GPUs (run below) should be around 2-5ms/batch.

# %%
try:
    with tf.Session() as sess:
        with tf.device("/gpu:0") as dev: #"/cpu:0" or "/gpu:0"
            tf.global_variables_initializer().run()

            ans = sess.run(y_out,feed_dict={X:x,is_training:True})
            # %timeit sess.run(y_out,feed_dict={X:x,is_training:True})
except tf.errors.InvalidArgumentError:
    print("no gpu found, please use Google Cloud if you want GPU acceleration")    
    # rebuild the graph
    # trying to start a GPU throws an exception 
    # and also trashes the original graph
    tf.reset_default_graph()
    X = tf.placeholder(tf.float32, [None, 32, 32, 3])
    y = tf.placeholder(tf.int64, [None])
    is_training = tf.placeholder(tf.bool)
    y_out = complex_model(X,y,is_training)

# %% [markdown]
# You should observe that even a simple forward pass like this is significantly faster on the GPU. So for the rest of the assignment (and when you go train your models in assignment 3 and your project!), you should use GPU devices. However, with TensorFlow, the default device is a GPU if one is available, and a CPU otherwise, so we can skip the device specification from now on.

# %% [markdown]
# ### Train the model.
#
# Now that you've seen how to define a model and do a single forward pass of some data through it, let's  walk through how you'd actually train one whole epoch over your training data (using the complex_model you created provided above).
#
# Make sure you understand how each TensorFlow function used below corresponds to what you implemented in your custom neural network implementation.
#
# First, set up an **RMSprop optimizer** (using a 1e-3 learning rate) and a **cross-entropy loss** function. See the TensorFlow documentation for more information
# * Layers, Activations, Loss functions : https://www.tensorflow.org/api_guides/python/nn
# * Optimizers: https://www.tensorflow.org/api_guides/python/train#Optimizers

# %%
# Inputs
#     y_out: is what your model computes
#     y: is your TensorFlow variable with label information
# Outputs
#    mean_loss: a TensorFlow variable (scalar) with numerical loss
#    optimizer: a TensorFlow optimizer
# This should be ~3 lines of code!
total_loss = tf.nn.softmax_cross_entropy_with_logits_v2(labels=tf.one_hot(y,10), logits=y_out)
mean_loss = tf.reduce_mean(total_loss)
optimizer = tf.train.RMSPropOptimizer(learning_rate=1e-3)

# %%
# batch normalization in tensorflow requires this extra dependency
extra_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
with tf.control_dependencies(extra_update_ops):
    train_step = optimizer.minimize(mean_loss)

# %% [markdown]
# ### Train the model
# Below we'll create a session and train the model over one epoch. You should see a loss of 1.4 to 2.0 and an accuracy of 0.4 to 0.5. There will be some variation due to random seeds and differences in initialization

# %%
sess = tf.Session()

sess.run(tf.global_variables_initializer())
print('Training')
run_model(sess,y_out,mean_loss,X,y,is_training,X_train,y_train,1,64,100,train_step)

# %% [markdown]
# ### Check the accuracy of the model.
#
# Let's see the train and test code in action -- feel free to use these methods when evaluating the models you develop below. You should see a loss of 1.3 to 2.0 with an accuracy of 0.45 to 0.55.

# %%
print('Validation')
run_model(sess,y_out,mean_loss,X,y,is_training,X_val,y_val,1,64)

# %% [markdown]
# ## Train a _great_ model on CIFAR-10!
#
# Now it's your job to experiment with architectures, hyperparameters, loss functions, and optimizers to train a model that achieves ** >= 70% accuracy on the validation set** of CIFAR-10. You can use the `run_model` function from above.

# %% [markdown]
# ### Things you should try:
# - **Filter size**: Above we used 7x7; this makes pretty pictures but smaller filters may be more efficient
# - **Number of filters**: Above we used 32 filters. Do more or fewer do better?
# - **Pooling vs Strided Convolution**: Do you use max pooling or just stride convolutions?
# - **Batch normalization**: Try adding spatial batch normalization after convolution layers and vanilla batch normalization after affine layers. Do your networks train faster?
# - **Network architecture**: The network above has two layers of trainable parameters. Can you do better with a deep network? Good architectures to try include:
#     - [conv-relu-pool]xN -> [affine]xM -> [softmax or SVM]
#     - [conv-relu-conv-relu-pool]xN -> [affine]xM -> [softmax or SVM]
#     - [batchnorm-relu-conv]xN -> [affine]xM -> [softmax or SVM]
# - **Use TensorFlow Scope**: Use TensorFlow scope and/or [tf.layers](https://www.tensorflow.org/api_docs/python/tf/layers) to make it easier to write deeper networks. See [this tutorial](https://www.tensorflow.org/tutorials/layers) for how to use `tf.layers`.
# - **Use Learning Rate Decay**: [As the notes point out](http://cs231n.github.io/neural-networks-3/#anneal), decaying the learning rate might help the model converge. Feel free to decay every epoch, when loss doesn't change over an entire epoch, or any other heuristic you find appropriate. See the [Tensorflow documentation](https://www.tensorflow.org/versions/master/api_guides/python/train#Decaying_the_learning_rate) for learning rate decay.
# - **Global Average Pooling**: Instead of flattening and then having multiple affine layers, perform convolutions until your image gets small (7x7 or so) and then perform an average pooling operation to get to a 1x1 image picture (1, 1 , Filter#), which is then reshaped into a (Filter#) vector. This is used in [Google's Inception Network](https://arxiv.org/abs/1512.00567) (See Table 1 for their architecture).
# - **Regularization**: Add l2 weight regularization, or perhaps use [Dropout as in the TensorFlow MNIST tutorial](https://www.tensorflow.org/get_started/mnist/pros)
#
# ### Tips for training
# For each network architecture that you try, you should tune the learning rate and regularization strength. When doing this there are a couple important things to keep in mind:
#
# - If the parameters are working well, you should see improvement within a few hundred iterations
# - Remember the coarse-to-fine approach for hyperparameter tuning: start by testing a large range of hyperparameters for just a few training iterations to find the combinations of parameters that are working at all.
# - Once you have found some sets of parameters that seem to work, search more finely around these parameters. You may need to train for more epochs.
# - You should use the validation set for hyperparameter search, and we'll save the test set for evaluating your architecture on the best parameters as selected by the validation set.
#
# ### Going above and beyond
# If you are feeling adventurous there are many other features you can implement to try and improve your performance. You are **not required** to implement any of these; however they would be good things to try for extra credit.
#
# - Alternative update steps: For the assignment we implemented SGD+momentum, RMSprop, and Adam; you could try alternatives like AdaGrad or AdaDelta.
# - Alternative activation functions such as leaky ReLU, parametric ReLU, ELU, or MaxOut.
# - Model ensembles
# - Data augmentation
# - New Architectures
#   - [ResNets](https://arxiv.org/abs/1512.03385) where the input from the previous layer is added to the output.
#   - [DenseNets](https://arxiv.org/abs/1608.06993) where inputs into previous layers are concatenated together.
#   - [This blog has an in-depth overview](https://chatbotslife.com/resnets-highwaynets-and-densenets-oh-my-9bb15918ee32)
#
# If you do decide to implement something extra, clearly describe it in the "Extra Credit Description" cell below.
#
# ### What we expect
# At the very least, you should be able to train a ConvNet that gets at **>= 70% accuracy on the validation set**. This is just a lower bound - if you are careful it should be possible to get accuracies much higher than that! Extra credit points will be awarded for particularly high-scoring models or unique approaches.
#
# You should use the space below to experiment and train your network. The final cell in this notebook should contain the training and validation set accuracies for your final trained network.
#
# Have fun and happy training!

# %%
def test_dimension(model, x, X, y, is_training, options):
    y_out = model(X, y, is_training, options)
    with tf.Session() as sess, tf.device("/cpu:0"):
        tf.global_variables_initializer().run()

        ans = sess.run(y_out,feed_dict={X:x,is_training:True})
        print('\n')
        print(ans.shape)

# %%
# Feel free to play with this cell
def key_conv(i):
    return "conv" + str(i)


def key_affine(i):
    return "affine" + str(i)


def my_model(X, y, is_training, options):
    N, f, k_conv, s_conv = options
    out = X
    for n in range(N):
        with tf.variable_scope(key_conv(n)):
#             print(out.shape)
            # (in - filter + 1) / stride
            # (32 - 7 + 1) / 1 = 26 => [None, 26, 26, 32]
            # (26 - 7 + 1) / 1 = 20 => [None, 20, 20, 32]
            # (20 - 7 + 1) / 1 = 14 => [None, 14, 14, 32]
            # (14 - 7 + 1) / 1 = 8 => [None, 8, 8, 32]
            out = tf.layers.conv2d(
                inputs=out,
                filters=f,
                kernel_size=k_conv,
                strides=s_conv,
                padding="valid",
                activation=tf.nn.relu)
            out = tf.layers.batch_normalization(out, training=is_training)

#     print('\n')
#     print(out.shape)
    out = tf.layers.average_pooling2d(out, out.shape[1:3], 1)
#     print(out.shape)
    out = tf.layers.dense(inputs=out, units=10)
    out = tf.layers.batch_normalization(out, training=is_training)
    out = tf.reshape(out, [-1, out.shape[-1]])
#     print(out.shape)

#     for item in tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES):
#         print("%s\t%s" % (item.name, item.shape))
#     for m in xrange(M):
#         with tf.variable_scope(key_affine(m)):
#             dense = tf.layers.dense(inputs=out_pool, units=1024)
    return out

# %%
tf.reset_default_graph()

x = np.random.randn(64, 32, 32, 3)

X = tf.placeholder(tf.float32, [None, 32, 32, 3])
y = tf.placeholder(tf.int64, [None])
is_training = tf.placeholder(tf.bool)

N, f = 4, 32
k_conv, s_conv = 7, 1
options = (N, f, k_conv, s_conv)

test_dimension(my_model, x, X, y, is_training, options)
# Out:
# (64, 10)

# %%
# Feel free to play with this cell
# This default code creates a session
# and trains your model for 10 epochs
# then prints the validation set accuracy
def test_model(model, options, learning_rate=1e-3):
    graph = tf.Graph()
    with graph.as_default():
#         tf.reset_default_graph()

        X = tf.placeholder(tf.float32, [None, 32, 32, 3])
        y = tf.placeholder(tf.int64, [None])
        is_training = tf.placeholder(tf.bool)

        y_out = model(X, y, is_training, options)

        total_loss = tf.nn.softmax_cross_entropy_with_logits_v2(labels=tf.one_hot(y, 10), logits=y_out)
        mean_loss = tf.reduce_mean(total_loss)
        optimizer = tf.train.RMSPropOptimizer(learning_rate=learning_rate)

        # batch normalization in tensorflow requires this extra dependency
        extra_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
        with tf.control_dependencies(extra_update_ops):
            train_step = optimizer.minimize(mean_loss)
    
    with tf.Session(graph=graph) as sess:
        sess.run(tf.global_variables_initializer())
        print('Training')
        # run_model(sess,y_out,mean_loss,X,y,is_training,X_train[:100],y_train[:100],
        #           epochs=10, batch_size=64, print_every=100, training=train_step, plot_losses=True)
#         print(y.graph)
#         print(y_out.graph)
#         print(is_training.graph)
#         print(train_step.graph)
        run_model(sess,y_out,mean_loss,X,y,is_training,X_train[:100],y_train[:100],
                  epochs=5, batch_size=64, print_every=100, training=train_step, plot_losses=False, graph=graph)
        print('Validation')
        return run_model(sess,y_out,mean_loss,X,y,is_training,X_val,y_val,
                  epochs=1, batch_size=64, graph=graph)

# %%
N, f = 4, 32
k_conv, s_conv = 7, 1
# learning_rate = 1e-3
options = (N, f, k_conv, s_conv)

best_accuracy = 0
best_stats = None

for i in xrange(100):
    learning_rate = 10 ** np.random.uniform(-4, -2)
    loss, accuracy = test_model(my_model, options, learning_rate=learning_rate)
    print("\nlearning_rate %f:\n\taccuracy: %f\tloss: %f\n" % (learning_rate, accuracy, loss))
    
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_stats = (learning_rate)

print("best_accuracy: %f\nlearning_rate:%f", best_accuracy, learning_rate)
# test_model(complex_model, options)
# Out:
# Training
# Iteration 0: with minibatch training loss = 2.65 and accuracy of 0.12
# Epoch 1, Overall loss = 1.69 and accuracy of 0.08
# Epoch 2, Overall loss = 1.19 and accuracy of 0.24
# Epoch 3, Overall loss = 0.937 and accuracy of 0.35
# Epoch 4, Overall loss = 0.771 and accuracy of 0.51
# Epoch 5, Overall loss = 0.675 and accuracy of 0.58
# Validation
# Epoch 1, Overall loss = 2.87 and accuracy of 0.098
#
# learning_rate 0.007964:
# 	accuracy: 0.098000	loss: 2.865189
#
# Training
# Iteration 0: with minibatch training loss = 3.05 and accuracy of 0.12
# Epoch 1, Overall loss = 1.95 and accuracy of 0.08
# Epoch 2, Overall loss = 1.73 and accuracy of 0.14
# Epoch 3, Overall loss = 1.53 and accuracy of 0.19
# Epoch 4, Overall loss = 1.36 and accuracy of 0.22
# Epoch 5, Overall loss = 1.23 and accuracy of 0.23
# Validation
# Epoch 1, Overall loss = 8.28 and accuracy of 0.073
#
# learning_rate 0.002805:
# 	accuracy: 0.073000	loss: 8.279326
#
# Training
# Iteration 0: with minibatch training loss = 2.84 and accuracy of 0.11
# Epoch 1, Overall loss = 1.82 and accuracy of 0.07
# Epoch 2, Overall loss = 1.46 and accuracy of 0.09
# Epoch 3, Overall loss = 1.24 and accuracy of 0.13
# Epoch 4, Overall loss = 1.07 and accuracy of 0.29
# Epoch 5, Overall loss = 0.924 and accuracy of 0.37
# Validation
# Epoch 1, Overall loss = 2.58 and accuracy of 0.118
#
# learning_rate 0.003928:
# 	accuracy: 0.118000	loss: 2.584453
#
# Training
# Iteration 0: with minibatch training loss = 2.97 and accuracy of 0.12
# Epoch 1, Overall loss = 1.9 and accuracy of 0.08
# Epoch 2, Overall loss = 1.78 and accuracy of 0.09
# Epoch 3, Overall loss = 1.65 and accuracy of 0.11
# Epoch 4, Overall loss = 1.52 and accuracy of 0.14
# Epoch 5, Overall loss = 1.39 and accuracy of 0.16
# Validation
# Epoch 1, Overall loss = 3.18 and accuracy of 0.079
#
# learning_rate 0.000958:
# 	accuracy: 0.079000	loss: 3.175208
#
# Training
# Iteration 0: with minibatch training loss = 2.6 and accuracy of 0.12
# Epoch 1, Overall loss = 1.66 and accuracy of 0.08
# Epoch 2, Overall loss = 1.47 and accuracy of 0.09
# Epoch 3, Overall loss = 1.32 and accuracy of 0.14
# Epoch 4, Overall loss = 1.21 and accuracy of 0.21
# Epoch 5, Overall loss = 1.1 and accuracy of 0.27
# Validation
# Epoch 1, Overall loss = 3.88 and accuracy of 0.076
#
# learning_rate 0.001786:
# 	accuracy: 0.076000	loss: 3.875289
#
# Training
# Iteration 0: with minibatch training loss = 2.76 and accuracy of 0.11
# Epoch 1, Overall loss = 1.76 and accuracy of 0.07
# Epoch 2, Overall loss = 1.73 and accuracy of 0.07
# Epoch 3, Overall loss = 1.69 and accuracy of 0.07
# Epoch 4, Overall loss = 1.65 and accuracy of 0.08
# Epoch 5, Overall loss = 1.61 and accuracy of 0.1
# Validation
# Epoch 1, Overall loss = 4.8 and accuracy of 0.093
#
# learning_rate 0.000210:
# 	accuracy: 0.093000	loss: 4.795793
#
# Training
# Iteration 0: with minibatch training loss = 2.6 and accuracy of 0.14
# Epoch 1, Overall loss = 1.66 and accuracy of 0.09
# Epoch 2, Overall loss = 1.5 and accuracy of 0.12
# Epoch 3, Overall loss = 1.36 and accuracy of 0.13
# Epoch 4, Overall loss = 1.26 and accuracy of 0.16
# Epoch 5, Overall loss = 1.16 and accuracy of 0.19
# Validation
# Epoch 1, Overall loss = 3.87 and accuracy of 0.082
#
# learning_rate 0.001294:
# 	accuracy: 0.082000	loss: 3.872907
#
# Training
# Iteration 0: with minibatch training loss = 2.73 and accuracy of 0.031
# Epoch 1, Overall loss = 1.75 and accuracy of 0.02
# Epoch 2, Overall loss = 1.37 and accuracy of 0.16
# Epoch 3, Overall loss = 1.16 and accuracy of 0.23
# Epoch 4, Overall loss = 0.988 and accuracy of 0.36
# Epoch 5, Overall loss = 0.881 and accuracy of 0.44
# Validation
# Epoch 1, Overall loss = 3.72 and accuracy of 0.088
#
# learning_rate 0.006913:
# 	accuracy: 0.088000	loss: 3.720294
#
# Training
# Iteration 0: with minibatch training loss = 2.66 and accuracy of 0.094
# Epoch 1, Overall loss = 1.7 and accuracy of 0.06
# Epoch 2, Overall loss = 1.53 and accuracy of 0.07
# Epoch 3, Overall loss = 1.4 and accuracy of 0.11
# Epoch 4, Overall loss = 1.3 and accuracy of 0.17
# Epoch 5, Overall loss = 1.22 and accuracy of 0.18
# Validation
# Epoch 1, Overall loss = 3.34 and accuracy of 0.112
#
# learning_rate 0.001481:
# 	accuracy: 0.112000	loss: 3.339277
#
# Training
# Iteration 0: with minibatch training loss = 2.84 and accuracy of 0.031
# Epoch 1, Overall loss = 1.82 and accuracy of 0.02
# Epoch 2, Overall loss = 1.52 and accuracy of 0.1
# Epoch 3, Overall loss = 1.3 and accuracy of 0.19
# Epoch 4, Overall loss = 1.16 and accuracy of 0.22
# Epoch 5, Overall loss = 1.05 and accuracy of 0.3
# Validation
# Epoch 1, Overall loss = 2.92 and accuracy of 0.096
#
# learning_rate 0.002976:
# 	accuracy: 0.096000	loss: 2.919408
#
# Training
# Iteration 0: with minibatch training loss = 2.51 and accuracy of 0.078
# Epoch 1, Overall loss = 1.6 and accuracy of 0.05
# Epoch 2, Overall loss = 1.53 and accuracy of 0.08
# Epoch 3, Overall loss = 1.46 and accuracy of 0.09
# Epoch 4, Overall loss = 1.4 and accuracy of 0.1
# Epoch 5, Overall loss = 1.35 and accuracy of 0.13
# Validation
# Epoch 1, Overall loss = 3.12 and accuracy of 0.086
#
# learning_rate 0.000782:
# 	accuracy: 0.086000	loss: 3.121532
#
# Training
# Iteration 0: with minibatch training loss = 2.76 and accuracy of 0.078
# Epoch 1, Overall loss = 1.76 and accuracy of 0.05
# Epoch 2, Overall loss = 1.46 and accuracy of 0.09
# Epoch 3, Overall loss = 1.27 and accuracy of 0.21
# Epoch 4, Overall loss = 1.13 and accuracy of 0.26
# Epoch 5, Overall loss = 1.01 and accuracy of 0.35
# Validation
# Epoch 1, Overall loss = 3.99 and accuracy of 0.082
#
# learning_rate 0.004652:
# 	accuracy: 0.082000	loss: 3.990174
#
# Training
# Iteration 0: with minibatch training loss = 2.62 and accuracy of 0.2
# Epoch 1, Overall loss = 1.68 and accuracy of 0.13
# Epoch 2, Overall loss = 1.65 and accuracy of 0.15
# Epoch 3, Overall loss = 1.62 and accuracy of 0.15
# Epoch 4, Overall loss = 1.59 and accuracy of 0.15
# Epoch 5, Overall loss = 1.56 and accuracy of 0.14
# Validation
# Epoch 1, Overall loss = 6.87 and accuracy of 0.076
#
# learning_rate 0.000497:
# 	accuracy: 0.076000	loss: 6.873823
#
# Training
# Iteration 0: with minibatch training loss = 2.63 and accuracy of 0.094
# Epoch 1, Overall loss = 1.68 and accuracy of 0.06
# Epoch 2, Overall loss = 1.67 and accuracy of 0.06
# Epoch 3, Overall loss = 1.65 and accuracy of 0.06
# Epoch 4, Overall loss = 1.63 and accuracy of 0.07
# Epoch 5, Overall loss = 1.61 and accuracy of 0.07
# Validation
# Epoch 1, Overall loss = 2.77 and accuracy of 0.105
#
# learning_rate 0.000175:
# 	accuracy: 0.105000	loss: 2.770217
#
# Training
# Iteration 0: with minibatch training loss = 2.7 and accuracy of 0.047
# Epoch 1, Overall loss = 1.73 and accuracy of 0.03
# Epoch 2, Overall loss = 1.67 and accuracy of 0.04
# Epoch 3, Overall loss = 1.61 and accuracy of 0.05
# Epoch 4, Overall loss = 1.55 and accuracy of 0.1
# Epoch 5, Overall loss = 1.5 and accuracy of 0.15
# Validation
# Epoch 1, Overall loss = 2.96 and accuracy of 0.111
#
# learning_rate 0.000545:
# 	accuracy: 0.111000	loss: 2.955509
#
# Training
# Iteration 0: with minibatch training loss = 2.86 and accuracy of 0.031
# Epoch 1, Overall loss = 1.83 and accuracy of 0.02
# Epoch 2, Overall loss = 1.8 and accuracy of 0.02
# Epoch 3, Overall loss = 1.77 and accuracy of 0.02
# Epoch 4, Overall loss = 1.73 and accuracy of 0.04
# Epoch 5, Overall loss = 1.7 and accuracy of 0.06
# Validation
# Epoch 1, Overall loss = 3.11 and accuracy of 0.103
#
# learning_rate 0.000322:
# 	accuracy: 0.103000	loss: 3.109789
#
# Training
# Iteration 0: with minibatch training loss = 2.59 and accuracy of 0.062
# Epoch 1, Overall loss = 1.66 and accuracy of 0.04
# Epoch 2, Overall loss = 1.64 and accuracy of 0.04
# Epoch 3, Overall loss = 1.63 and accuracy of 0.05
# Epoch 4, Overall loss = 1.61 and accuracy of 0.09
# Epoch 5, Overall loss = 1.6 and accuracy of 0.09
# Validation
# Epoch 1, Overall loss = 4.38 and accuracy of 0.074
#
# learning_rate 0.000161:
# 	accuracy: 0.074000	loss: 4.382973
#
# Training
# Iteration 0: with minibatch training loss = 2.73 and accuracy of 0.12
# Epoch 1, Overall loss = 1.75 and accuracy of 0.08
# Epoch 2, Overall loss = 1.4 and accuracy of 0.13
# Epoch 3, Overall loss = 1.19 and accuracy of 0.2
# Epoch 4, Overall loss = 1.01 and accuracy of 0.28
# Epoch 5, Overall loss = 0.894 and accuracy of 0.4
# Validation
# Epoch 1, Overall loss = 2.93 and accuracy of 0.118
#
# learning_rate 0.005383:
# 	accuracy: 0.118000	loss: 2.926489
#
# Training
# Iteration 0: with minibatch training loss = 2.62 and accuracy of 0.078
# Epoch 1, Overall loss = 1.68 and accuracy of 0.05
# Epoch 2, Overall loss = 1.56 and accuracy of 0.12
# Epoch 3, Overall loss = 1.44 and accuracy of 0.15
# Epoch 4, Overall loss = 1.33 and accuracy of 0.17
# Epoch 5, Overall loss = 1.23 and accuracy of 0.17
# Validation
# Epoch 1, Overall loss = 3.39 and accuracy of 0.084
#
# learning_rate 0.001295:
# 	accuracy: 0.084000	loss: 3.388005
#
# Training
# Iteration 0: with minibatch training loss = 2.92 and accuracy of 0.078
# Epoch 1, Overall loss = 1.87 and accuracy of 0.05
# Epoch 2, Overall loss = 1.83 and accuracy of 0.05
# Epoch 3, Overall loss = 1.79 and accuracy of 0.05
# Epoch 4, Overall loss = 1.75 and accuracy of 0.06
# Epoch 5, Overall loss = 1.7 and accuracy of 0.07
# Validation
# Epoch 1, Overall loss = 4.1 and accuracy of 0.076
#
# learning_rate 0.000279:
# 	accuracy: 0.076000	loss: 4.097395
#
# Training
# Iteration 0: with minibatch training loss = 2.77 and accuracy of 0.047
# Epoch 1, Overall loss = 1.77 and accuracy of 0.03
# Epoch 2, Overall loss = 1.75 and accuracy of 0.05
# Epoch 3, Overall loss = 1.72 and accuracy of 0.04
# Epoch 4, Overall loss = 1.69 and accuracy of 0.05
# Epoch 5, Overall loss = 1.66 and accuracy of 0.06
# Validation
# Epoch 1, Overall loss = 3.05 and accuracy of 0.124
#
# learning_rate 0.000200:
# 	accuracy: 0.124000	loss: 3.051947
#
# Training
# Iteration 0: with minibatch training loss = 2.7 and accuracy of 0.12
# Epoch 1, Overall loss = 1.73 and accuracy of 0.08
# Epoch 2, Overall loss = 1.7 and accuracy of 0.08
# Epoch 3, Overall loss = 1.68 and accuracy of 0.08
# Epoch 4, Overall loss = 1.65 and accuracy of 0.09
# Epoch 5, Overall loss = 1.62 and accuracy of 0.1
# Validation
# Epoch 1, Overall loss = 3.21 and accuracy of 0.114
#
# learning_rate 0.000300:
# 	accuracy: 0.114000	loss: 3.213374
#
# Training
# Iteration 0: with minibatch training loss = 2.66 and accuracy of 0.14
# Epoch 1, Overall loss = 1.7 and accuracy of 0.09
# Epoch 2, Overall loss = 1.69 and accuracy of 0.09
# Epoch 3, Overall loss = 1.68 and accuracy of 0.09
# Epoch 4, Overall loss = 1.66 and accuracy of 0.1
# Epoch 5, Overall loss = 1.65 and accuracy of 0.1
# Validation
# Epoch 1, Overall loss = 4.4 and accuracy of 0.068
#
# learning_rate 0.000118:
# 	accuracy: 0.068000	loss: 4.397119
#
# Training
# Iteration 0: with minibatch training loss = 2.48 and accuracy of 0.16
# Epoch 1, Overall loss = 1.59 and accuracy of 0.1
# Epoch 2, Overall loss = 1.22 and accuracy of 0.23
# Epoch 3, Overall loss = 1.06 and accuracy of 0.32
# Epoch 4, Overall loss = 0.953 and accuracy of 0.34
# Epoch 5, Overall loss = 0.892 and accuracy of 0.4
# Validation
# Epoch 1, Overall loss = 3.23 and accuracy of 0.071
#
# learning_rate 0.004472:
# 	accuracy: 0.071000	loss: 3.226209
#
# Training
# Iteration 0: with minibatch training loss = 2.97 and accuracy of 0.062
# Epoch 1, Overall loss = 1.9 and accuracy of 0.04
# Epoch 2, Overall loss = 1.87 and accuracy of 0.04
# Epoch 3, Overall loss = 1.83 and accuracy of 0.04
# Epoch 4, Overall loss = 1.79 and accuracy of 0.04
# Epoch 5, Overall loss = 1.75 and accuracy of 0.05
# Validation
# Epoch 1, Overall loss = 4.31 and accuracy of 0.107
#
# learning_rate 0.000653:
# 	accuracy: 0.107000	loss: 4.313215
#
# Training
# Iteration 0: with minibatch training loss = 2.95 and accuracy of 0.078
# Epoch 1, Overall loss = 1.89 and accuracy of 0.05
# Epoch 2, Overall loss = 1.44 and accuracy of 0.14
# Epoch 3, Overall loss = 1.18 and accuracy of 0.23
# Epoch 4, Overall loss = 1.03 and accuracy of 0.33
# Epoch 5, Overall loss = 0.928 and accuracy of 0.36
# Validation
# Epoch 1, Overall loss = 2.73 and accuracy of 0.106
#
# learning_rate 0.004408:
# 	accuracy: 0.106000	loss: 2.730752
#
# Training
# Iteration 0: with minibatch training loss = 2.67 and accuracy of 0.14
# Epoch 1, Overall loss = 1.71 and accuracy of 0.09
# Epoch 2, Overall loss = 1.61 and accuracy of 0.1
# Epoch 3, Overall loss = 1.52 and accuracy of 0.11
# Epoch 4, Overall loss = 1.45 and accuracy of 0.13
# Epoch 5, Overall loss = 1.38 and accuracy of 0.13
# Validation
# Epoch 1, Overall loss = 3.24 and accuracy of 0.08
#
# learning_rate 0.000658:
# 	accuracy: 0.080000	loss: 3.244404
#
# Training
# Iteration 0: with minibatch training loss = 2.5 and accuracy of 0.16
# Epoch 1, Overall loss = 1.6 and accuracy of 0.1
# Epoch 2, Overall loss = 1.59 and accuracy of 0.1
# Epoch 3, Overall loss = 1.58 and accuracy of 0.11
# Epoch 4, Overall loss = 1.57 and accuracy of 0.11
# Epoch 5, Overall loss = 1.56 and accuracy of 0.12
# Validation
# Epoch 1, Overall loss = 2.64 and accuracy of 0.118
#
# learning_rate 0.000102:
# 	accuracy: 0.118000	loss: 2.640684
#
# Training
# Iteration 0: with minibatch training loss = 2.62 and accuracy of 0.078
# Epoch 1, Overall loss = 1.68 and accuracy of 0.05
# Epoch 2, Overall loss = 1.66 and accuracy of 0.05
# Epoch 3, Overall loss = 1.64 and accuracy of 0.06
# Epoch 4, Overall loss = 1.62 and accuracy of 0.08
# Epoch 5, Overall loss = 1.61 and accuracy of 0.08
# Validation
# Epoch 1, Overall loss = 3.96 and accuracy of 0.089
#
# learning_rate 0.000178:
# 	accuracy: 0.089000	loss: 3.959192
#
# Training
# Iteration 0: with minibatch training loss = 2.71 and accuracy of 0.11
# Epoch 1, Overall loss = 1.73 and accuracy of 0.07
# Epoch 2, Overall loss = 1.27 and accuracy of 0.2
# Epoch 3, Overall loss = 0.965 and accuracy of 0.33
# Epoch 4, Overall loss = 0.812 and accuracy of 0.43
# Epoch 5, Overall loss = 0.802 and accuracy of 0.47
# Validation
# Epoch 1, Overall loss = 2.92 and accuracy of 0.106
#
# learning_rate 0.007528:
# 	accuracy: 0.106000	loss: 2.917777
#
# Training
# Iteration 0: with minibatch training loss = 2.74 and accuracy of 0.016
# Epoch 1, Overall loss = 1.75 and accuracy of 0.01
# Epoch 2, Overall loss = 1.48 and accuracy of 0.1
# Epoch 3, Overall loss = 1.29 and accuracy of 0.2
# Epoch 4, Overall loss = 1.14 and accuracy of 0.24
# Epoch 5, Overall loss = 1.03 and accuracy of 0.32
# Validation
# Epoch 1, Overall loss = 3.77 and accuracy of 0.104
#
# learning_rate 0.002003:
# 	accuracy: 0.104000	loss: 3.768076
#
# Training
# Iteration 0: with minibatch training loss = 2.69 and accuracy of 0.094
# Epoch 1, Overall loss = 1.72 and accuracy of 0.06
# Epoch 2, Overall loss = 1.65 and accuracy of 0.06
# Epoch 3, Overall loss = 1.57 and accuracy of 0.08
# Epoch 4, Overall loss = 1.5 and accuracy of 0.11
# Epoch 5, Overall loss = 1.43 and accuracy of 0.15
# Validation
# Epoch 1, Overall loss = 3.39 and accuracy of 0.073
#
# learning_rate 0.000776:
# 	accuracy: 0.073000	loss: 3.385039
#
# Training
# Iteration 0: with minibatch training loss = 2.7 and accuracy of 0.078
# Epoch 1, Overall loss = 1.73 and accuracy of 0.05
# Epoch 2, Overall loss = 1.18 and accuracy of 0.23
# Epoch 3, Overall loss = 0.93 and accuracy of 0.38
# Epoch 4, Overall loss = 0.817 and accuracy of 0.51
# Epoch 5, Overall loss = 0.791 and accuracy of 0.43
# Validation
# Epoch 1, Overall loss = 3.42 and accuracy of 0.14
#
# learning_rate 0.007753:
# 	accuracy: 0.140000	loss: 3.421422
#
# Training
# Iteration 0: with minibatch training loss = 2.63 and accuracy of 0.031
# Epoch 1, Overall loss = 1.68 and accuracy of 0.02
# Epoch 2, Overall loss = 1.5 and accuracy of 0.06
# Epoch 3, Overall loss = 1.34 and accuracy of 0.12
# Epoch 4, Overall loss = 1.22 and accuracy of 0.19
# Epoch 5, Overall loss = 1.12 and accuracy of 0.21
# Validation
# Epoch 1, Overall loss = 2.49 and accuracy of 0.102
#
# learning_rate 0.001322:
# 	accuracy: 0.102000	loss: 2.486257
#
# Training
# Iteration 0: with minibatch training loss = 2.69 and accuracy of 0.094
# Epoch 1, Overall loss = 1.72 and accuracy of 0.06
# Epoch 2, Overall loss = 1.19 and accuracy of 0.21
# Epoch 3, Overall loss = 0.965 and accuracy of 0.35
# Epoch 4, Overall loss = 0.894 and accuracy of 0.41
# Epoch 5, Overall loss = 0.846 and accuracy of 0.39
# Validation
# Epoch 1, Overall loss = 3.75 and accuracy of 0.1
#
# learning_rate 0.008062:
# 	accuracy: 0.100000	loss: 3.748447
#
# Training
# Iteration 0: with minibatch training loss = 2.65 and accuracy of 0.047
# Epoch 1, Overall loss = 1.7 and accuracy of 0.03
# Epoch 2, Overall loss = 1.36 and accuracy of 0.16
# Epoch 3, Overall loss = 1.15 and accuracy of 0.24
# Epoch 4, Overall loss = 0.983 and accuracy of 0.34
# Epoch 5, Overall loss = 0.853 and accuracy of 0.39
# Validation
# Epoch 1, Overall loss = 2.94 and accuracy of 0.063
#
# learning_rate 0.004094:
# 	accuracy: 0.063000	loss: 2.944416
#
# Training
# Iteration 0: with minibatch training loss = 2.61 and accuracy of 0.12
# Epoch 1, Overall loss = 1.67 and accuracy of 0.08
# Epoch 2, Overall loss = 1.62 and accuracy of 0.08
# Epoch 3, Overall loss = 1.58 and accuracy of 0.11
# Epoch 4, Overall loss = 1.53 and accuracy of 0.11
# Epoch 5, Overall loss = 1.49 and accuracy of 0.11
# Validation
# Epoch 1, Overall loss = 3.67 and accuracy of 0.077
#
# learning_rate 0.000537:
# 	accuracy: 0.077000	loss: 3.674433
#
# Training
# Iteration 0: with minibatch training loss = 2.56 and accuracy of 0.17
# Epoch 1, Overall loss = 1.64 and accuracy of 0.11
# Epoch 2, Overall loss = 1.62 and accuracy of 0.11
# Epoch 3, Overall loss = 1.59 and accuracy of 0.12
# Epoch 4, Overall loss = 1.57 and accuracy of 0.13
# Epoch 5, Overall loss = 1.54 and accuracy of 0.14
# Validation
# Epoch 1, Overall loss = 2.89 and accuracy of 0.088
#
# learning_rate 0.000287:
# 	accuracy: 0.088000	loss: 2.891039
#
# Training
# Iteration 0: with minibatch training loss = 2.85 and accuracy of 0.094
# Epoch 1, Overall loss = 1.83 and accuracy of 0.06
# Epoch 2, Overall loss = 1.68 and accuracy of 0.07
# Epoch 3, Overall loss = 1.53 and accuracy of 0.12
# Epoch 4, Overall loss = 1.39 and accuracy of 0.15
# Epoch 5, Overall loss = 1.27 and accuracy of 0.21
# Validation
# Epoch 1, Overall loss = 3.29 and accuracy of 0.135
#
# learning_rate 0.001810:
# 	accuracy: 0.135000	loss: 3.285537
#
# Training
# Iteration 0: with minibatch training loss = 2.67 and accuracy of 0.094
# Epoch 1, Overall loss = 1.71 and accuracy of 0.06
# Epoch 2, Overall loss = 1.66 and accuracy of 0.07
# Epoch 3, Overall loss = 1.62 and accuracy of 0.08
# Epoch 4, Overall loss = 1.58 and accuracy of 0.09
# Epoch 5, Overall loss = 1.54 and accuracy of 0.1
# Validation
# Epoch 1, Overall loss = 3.74 and accuracy of 0.102
#
# learning_rate 0.000443:
# 	accuracy: 0.102000	loss: 3.737038
#
# Training
# Iteration 0: with minibatch training loss = 2.72 and accuracy of 0.078
# Epoch 1, Overall loss = 1.74 and accuracy of 0.05
# Epoch 2, Overall loss = 1.67 and accuracy of 0.06
# Epoch 3, Overall loss = 1.6 and accuracy of 0.08
# Epoch 4, Overall loss = 1.53 and accuracy of 0.08
# Epoch 5, Overall loss = 1.46 and accuracy of 0.09
# Validation
# Epoch 1, Overall loss = 3.54 and accuracy of 0.112
#
# learning_rate 0.000794:
# 	accuracy: 0.112000	loss: 3.540967
#
# Training
# Iteration 0: with minibatch training loss = 2.81 and accuracy of 0.047
# Epoch 1, Overall loss = 1.8 and accuracy of 0.03
# Epoch 2, Overall loss = 1.77 and accuracy of 0.03
# Epoch 3, Overall loss = 1.74 and accuracy of 0.03
# Epoch 4, Overall loss = 1.71 and accuracy of 0.03
# Epoch 5, Overall loss = 1.68 and accuracy of 0.03
# Validation
# Epoch 1, Overall loss = 4.5 and accuracy of 0.11
#
# learning_rate 0.000255:
# 	accuracy: 0.110000	loss: 4.496991
#
# Training
# Iteration 0: with minibatch training loss = 2.53 and accuracy of 0.12
# Epoch 1, Overall loss = 1.62 and accuracy of 0.08
# Epoch 2, Overall loss = 1.61 and accuracy of 0.08
# Epoch 3, Overall loss = 1.59 and accuracy of 0.08
# Epoch 4, Overall loss = 1.58 and accuracy of 0.08
# Epoch 5, Overall loss = 1.56 and accuracy of 0.09
# Validation
# Epoch 1, Overall loss = 3.44 and accuracy of 0.095
#
# learning_rate 0.000138:
# 	accuracy: 0.095000	loss: 3.443164
#
# Training
# Iteration 0: with minibatch training loss = 2.73 and accuracy of 0.094
# Epoch 1, Overall loss = 1.75 and accuracy of 0.06
# Epoch 2, Overall loss = 1.51 and accuracy of 0.1
# Epoch 3, Overall loss = 1.36 and accuracy of 0.16
# Epoch 4, Overall loss = 1.25 and accuracy of 0.21
# Epoch 5, Overall loss = 1.14 and accuracy of 0.26
# Validation
# Epoch 1, Overall loss = 2.99 and accuracy of 0.076
#
# learning_rate 0.001914:
# 	accuracy: 0.076000	loss: 2.991176
#
# Training
# Iteration 0: with minibatch training loss = 2.73 and accuracy of 0.047
# Epoch 1, Overall loss = 1.75 and accuracy of 0.03
# Epoch 2, Overall loss = 1.25 and accuracy of 0.19
# Epoch 3, Overall loss = 0.988 and accuracy of 0.32
# Epoch 4, Overall loss = 0.859 and accuracy of 0.42
# Epoch 5, Overall loss = 0.896 and accuracy of 0.39
# Validation
# Epoch 1, Overall loss = 2.49 and accuracy of 0.133
#
# learning_rate 0.007686:
# 	accuracy: 0.133000	loss: 2.485733
#
# Training
# Iteration 0: with minibatch training loss = 2.73 and accuracy of 0.047
# Epoch 1, Overall loss = 1.75 and accuracy of 0.03
# Epoch 2, Overall loss = 1.52 and accuracy of 0.07
# Epoch 3, Overall loss = 1.34 and accuracy of 0.13
# Epoch 4, Overall loss = 1.19 and accuracy of 0.19
# Epoch 5, Overall loss = 1.06 and accuracy of 0.25
# Validation
# Epoch 1, Overall loss = 2.37 and accuracy of 0.115
#
# learning_rate 0.002379:
# 	accuracy: 0.115000	loss: 2.365938
#
# Training
# Iteration 0: with minibatch training loss = 2.88 and accuracy of 0.094
# Epoch 1, Overall loss = 1.84 and accuracy of 0.06
# Epoch 2, Overall loss = 1.82 and accuracy of 0.06
# Epoch 3, Overall loss = 1.8 and accuracy of 0.06
# Epoch 4, Overall loss = 1.77 and accuracy of 0.06
# Epoch 5, Overall loss = 1.74 and accuracy of 0.06
# Validation
# Epoch 1, Overall loss = 4.09 and accuracy of 0.081
#
# learning_rate 0.000198:
# 	accuracy: 0.081000	loss: 4.093375
#
# Training
# Iteration 0: with minibatch training loss = 2.59 and accuracy of 0.078
# Epoch 1, Overall loss = 1.66 and accuracy of 0.05
# Epoch 2, Overall loss = 1.33 and accuracy of 0.18
# Epoch 3, Overall loss = 1.09 and accuracy of 0.27
# Epoch 4, Overall loss = 0.936 and accuracy of 0.39
# Epoch 5, Overall loss = 0.836 and accuracy of 0.42
# Validation
# Epoch 1, Overall loss = 3.44 and accuracy of 0.093
#
# learning_rate 0.003730:
# 	accuracy: 0.093000	loss: 3.435308
#
# Training
# Iteration 0: with minibatch training loss = 2.81 and accuracy of 0.031
# Epoch 1, Overall loss = 1.8 and accuracy of 0.02
# Epoch 2, Overall loss = 1.73 and accuracy of 0.04
# Epoch 3, Overall loss = 1.67 and accuracy of 0.07
# Epoch 4, Overall loss = 1.6 and accuracy of 0.08
# Epoch 5, Overall loss = 1.54 and accuracy of 0.11
# Validation
# Epoch 1, Overall loss = 2.78 and accuracy of 0.1
#
# learning_rate 0.000542:
# 	accuracy: 0.100000	loss: 2.780397
#
# Training
# Iteration 0: with minibatch training loss = 2.58 and accuracy of 0.12
# Epoch 1, Overall loss = 1.65 and accuracy of 0.08
# Epoch 2, Overall loss = 1.25 and accuracy of 0.17
# Epoch 3, Overall loss = 1.07 and accuracy of 0.31
# Epoch 4, Overall loss = 0.941 and accuracy of 0.39
# Epoch 5, Overall loss = 0.835 and accuracy of 0.46
# Validation
# Epoch 1, Overall loss = 3.01 and accuracy of 0.116
#
# learning_rate 0.005508:
# 	accuracy: 0.116000	loss: 3.005093
#
# Training
# Iteration 0: with minibatch training loss = 2.72 and accuracy of 0.11
# Epoch 1, Overall loss = 1.74 and accuracy of 0.07
# Epoch 2, Overall loss = 1.71 and accuracy of 0.07
# Epoch 3, Overall loss = 1.68 and accuracy of 0.08
# Epoch 4, Overall loss = 1.65 and accuracy of 0.09
# Epoch 5, Overall loss = 1.62 and accuracy of 0.1
# Validation
# Epoch 1, Overall loss = 2.86 and accuracy of 0.082
#
# learning_rate 0.000366:
# 	accuracy: 0.082000	loss: 2.861220
#
# Training
# Iteration 0: with minibatch training loss = 2.89 and accuracy of 0.062
# Epoch 1, Overall loss = 1.85 and accuracy of 0.04
# Epoch 2, Overall loss = 1.43 and accuracy of 0.18
# Epoch 3, Overall loss = 1.1 and accuracy of 0.28
# Epoch 4, Overall loss = 0.844 and accuracy of 0.36
# Epoch 5, Overall loss = 0.846 and accuracy of 0.44
# Validation
# Epoch 1, Overall loss = 6.44 and accuracy of 0.109
#
# learning_rate 0.007823:
# 	accuracy: 0.109000	loss: 6.438230
#
# Training
# Iteration 0: with minibatch training loss = 2.71 and accuracy of 0.12
# Epoch 1, Overall loss = 1.74 and accuracy of 0.08
# Epoch 2, Overall loss = 1.7 and accuracy of 0.09
# Epoch 3, Overall loss = 1.65 and accuracy of 0.09
# Epoch 4, Overall loss = 1.61 and accuracy of 0.09
# Epoch 5, Overall loss = 1.57 and accuracy of 0.09
# Validation
# Epoch 1, Overall loss = 3.17 and accuracy of 0.104
#
# learning_rate 0.000298:
# 	accuracy: 0.104000	loss: 3.168097
#
# Training
# Iteration 0: with minibatch training loss = 2.71 and accuracy of 0.14
# Epoch 1, Overall loss = 1.73 and accuracy of 0.09
# Epoch 2, Overall loss = 1.69 and accuracy of 0.09
# Epoch 3, Overall loss = 1.65 and accuracy of 0.11
# Epoch 4, Overall loss = 1.6 and accuracy of 0.11
# Epoch 5, Overall loss = 1.55 and accuracy of 0.11
# Validation
# Epoch 1, Overall loss = 3.44 and accuracy of 0.098
#
# learning_rate 0.000263:
# 	accuracy: 0.098000	loss: 3.436179
#
# Training
# Iteration 0: with minibatch training loss = 2.82 and accuracy of 0.11
# Epoch 1, Overall loss = 1.8 and accuracy of 0.07
# Epoch 2, Overall loss = 1.43 and accuracy of 0.17
# Epoch 3, Overall loss = 1.17 and accuracy of 0.22
# Epoch 4, Overall loss = 1.01 and accuracy of 0.33
# Epoch 5, Overall loss = 0.908 and accuracy of 0.39
# Validation
# Epoch 1, Overall loss = 2.71 and accuracy of 0.116
#
# learning_rate 0.005618:
# 	accuracy: 0.116000	loss: 2.707739
#
# Training
# Iteration 0: with minibatch training loss = 2.44 and accuracy of 0.16
# Epoch 1, Overall loss = 1.56 and accuracy of 0.1
# Epoch 2, Overall loss = 1.38 and accuracy of 0.13
# Epoch 3, Overall loss = 1.21 and accuracy of 0.2
# Epoch 4, Overall loss = 1.05 and accuracy of 0.33
# Epoch 5, Overall loss = 0.904 and accuracy of 0.4
# Validation
# Epoch 1, Overall loss = 3.01 and accuracy of 0.15
#
# learning_rate 0.003512:
# 	accuracy: 0.150000	loss: 3.012690
#
# Training
# Iteration 0: with minibatch training loss = 2.57 and accuracy of 0.14
# Epoch 1, Overall loss = 1.64 and accuracy of 0.09
# Epoch 2, Overall loss = 1.34 and accuracy of 0.2
# Epoch 3, Overall loss = 1.13 and accuracy of 0.28
# Epoch 4, Overall loss = 0.935 and accuracy of 0.35
# Epoch 5, Overall loss = 0.848 and accuracy of 0.44
# Validation
# Epoch 1, Overall loss = 3.23 and accuracy of 0.134
#
# learning_rate 0.004687:
# 	accuracy: 0.134000	loss: 3.231405
#
# Training
# Iteration 0: with minibatch training loss = 2.71 and accuracy of 0.047
# Epoch 1, Overall loss = 1.74 and accuracy of 0.03
# Epoch 2, Overall loss = 1.6 and accuracy of 0.09
# Epoch 3, Overall loss = 1.48 and accuracy of 0.11
# Epoch 4, Overall loss = 1.38 and accuracy of 0.14
# Epoch 5, Overall loss = 1.28 and accuracy of 0.16
# Validation
# Epoch 1, Overall loss = 3.83 and accuracy of 0.087
#
# learning_rate 0.001503:
# 	accuracy: 0.087000	loss: 3.833587
#
# Training
# Iteration 0: with minibatch training loss = 2.72 and accuracy of 0.031
# Epoch 1, Overall loss = 1.74 and accuracy of 0.02
# Epoch 2, Overall loss = 1.73 and accuracy of 0.03
# Epoch 3, Overall loss = 1.71 and accuracy of 0.04
# Epoch 4, Overall loss = 1.69 and accuracy of 0.04
# Epoch 5, Overall loss = 1.67 and accuracy of 0.04
# Validation
# Epoch 1, Overall loss = 3.31 and accuracy of 0.115
#
# learning_rate 0.000114:
# 	accuracy: 0.115000	loss: 3.305936
#
# Training
# Iteration 0: with minibatch training loss = 2.6 and accuracy of 0.094
# Epoch 1, Overall loss = 1.67 and accuracy of 0.06
# Epoch 2, Overall loss = 1.55 and accuracy of 0.09
# Epoch 3, Overall loss = 1.45 and accuracy of 0.11
# Epoch 4, Overall loss = 1.36 and accuracy of 0.13
# Epoch 5, Overall loss = 1.28 and accuracy of 0.15
# Validation
# Epoch 1, Overall loss = 3.4 and accuracy of 0.081
#
# learning_rate 0.001394:
# 	accuracy: 0.081000	loss: 3.397839
#
# Training
# Iteration 0: with minibatch training loss = 2.72 and accuracy of 0.11
# Epoch 1, Overall loss = 1.74 and accuracy of 0.07
# Epoch 2, Overall loss = 1.43 and accuracy of 0.18
# Epoch 3, Overall loss = 1.21 and accuracy of 0.2
# Epoch 4, Overall loss = 1.05 and accuracy of 0.34
# Epoch 5, Overall loss = 0.932 and accuracy of 0.34
# Validation
# Epoch 1, Overall loss = 3.12 and accuracy of 0.098
#
# learning_rate 0.003913:
# 	accuracy: 0.098000	loss: 3.120090
#
# Training
# Iteration 0: with minibatch training loss = 2.67 and accuracy of 0.16
# Epoch 1, Overall loss = 1.71 and accuracy of 0.1
# Epoch 2, Overall loss = 1.49 and accuracy of 0.17
# Epoch 3, Overall loss = 1.3 and accuracy of 0.21
# Epoch 4, Overall loss = 1.13 and accuracy of 0.3
# Epoch 5, Overall loss = 0.983 and accuracy of 0.36
# Validation
# Epoch 1, Overall loss = 2.71 and accuracy of 0.115
#
# learning_rate 0.003466:
# 	accuracy: 0.115000	loss: 2.705328
#
# Training
# Iteration 0: with minibatch training loss = 2.88 and accuracy of 0.094
# Epoch 1, Overall loss = 1.84 and accuracy of 0.06
# Epoch 2, Overall loss = 1.62 and accuracy of 0.11
# Epoch 3, Overall loss = 1.41 and accuracy of 0.15
# Epoch 4, Overall loss = 1.25 and accuracy of 0.21
# Epoch 5, Overall loss = 1.13 and accuracy of 0.25
# Validation
# Epoch 1, Overall loss = 7.43 and accuracy of 0.076
#
# learning_rate 0.003567:
# 	accuracy: 0.076000	loss: 7.430400
#
# Training
# Iteration 0: with minibatch training loss = 2.68 and accuracy of 0.12
# Epoch 1, Overall loss = 1.71 and accuracy of 0.08
# Epoch 2, Overall loss = 1.68 and accuracy of 0.08
# Epoch 3, Overall loss = 1.64 and accuracy of 0.09
# Epoch 4, Overall loss = 1.6 and accuracy of 0.11
# Epoch 5, Overall loss = 1.56 and accuracy of 0.11
# Validation
# Epoch 1, Overall loss = 3.66 and accuracy of 0.103
#
# learning_rate 0.000332:
# 	accuracy: 0.103000	loss: 3.664594
#
# Training
# Iteration 0: with minibatch training loss = 2.66 and accuracy of 0.094
# Epoch 1, Overall loss = 1.7 and accuracy of 0.06
# Epoch 2, Overall loss = 1.68 and accuracy of 0.06
# Epoch 3, Overall loss = 1.66 and accuracy of 0.07
# Epoch 4, Overall loss = 1.63 and accuracy of 0.08
# Epoch 5, Overall loss = 1.61 and accuracy of 0.09
# Validation
# Epoch 1, Overall loss = 3.81 and accuracy of 0.097
#
# learning_rate 0.000158:
# 	accuracy: 0.097000	loss: 3.810076
#
# Training
# Iteration 0: with minibatch training loss = 2.92 and accuracy of 0.078
# Epoch 1, Overall loss = 1.87 and accuracy of 0.05
# Epoch 2, Overall loss = 1.6 and accuracy of 0.09
# Epoch 3, Overall loss = 1.42 and accuracy of 0.14
# Epoch 4, Overall loss = 1.28 and accuracy of 0.19
# Epoch 5, Overall loss = 1.16 and accuracy of 0.23
# Validation
# Epoch 1, Overall loss = 3.61 and accuracy of 0.125
#
# learning_rate 0.003017:
# 	accuracy: 0.125000	loss: 3.610357
#
# Training
# Iteration 0: with minibatch training loss = 2.73 and accuracy of 0.094
# Epoch 1, Overall loss = 1.75 and accuracy of 0.06
# Epoch 2, Overall loss = 1.71 and accuracy of 0.07
# Epoch 3, Overall loss = 1.67 and accuracy of 0.07
# Epoch 4, Overall loss = 1.63 and accuracy of 0.08
# Epoch 5, Overall loss = 1.59 and accuracy of 0.08
# Validation
# Epoch 1, Overall loss = 3.19 and accuracy of 0.116
#
# learning_rate 0.000346:
# 	accuracy: 0.116000	loss: 3.194595
#
# Training
# Iteration 0: with minibatch training loss = 2.82 and accuracy of 0.062
# Epoch 1, Overall loss = 1.8 and accuracy of 0.04
# Epoch 2, Overall loss = 1.39 and accuracy of 0.08
# Epoch 3, Overall loss = 1.2 and accuracy of 0.2
# Epoch 4, Overall loss = 1.05 and accuracy of 0.34
# Epoch 5, Overall loss = 0.926 and accuracy of 0.42
# Validation
# Epoch 1, Overall loss = 3.7 and accuracy of 0.099
#
# learning_rate 0.004539:
# 	accuracy: 0.099000	loss: 3.698434
#
# Training
# Iteration 0: with minibatch training loss = 2.74 and accuracy of 0.078
# Epoch 1, Overall loss = 1.75 and accuracy of 0.05
# Epoch 2, Overall loss = 1.69 and accuracy of 0.06
# Epoch 3, Overall loss = 1.64 and accuracy of 0.09
# Epoch 4, Overall loss = 1.58 and accuracy of 0.09
# Epoch 5, Overall loss = 1.53 and accuracy of 0.1
# Validation
# Epoch 1, Overall loss = 3.43 and accuracy of 0.1
#
# learning_rate 0.000379:
# 	accuracy: 0.100000	loss: 3.427841
#
# Training
# Iteration 0: with minibatch training loss = 2.88 and accuracy of 0.11
# Epoch 1, Overall loss = 1.84 and accuracy of 0.07
# Epoch 2, Overall loss = 1.79 and accuracy of 0.1
# Epoch 3, Overall loss = 1.74 and accuracy of 0.1
# Epoch 4, Overall loss = 1.69 and accuracy of 0.1
# Epoch 5, Overall loss = 1.63 and accuracy of 0.13
# Validation
# Epoch 1, Overall loss = 3.33 and accuracy of 0.139
#
# learning_rate 0.000452:
# 	accuracy: 0.139000	loss: 3.332767
#
# Training
# Iteration 0: with minibatch training loss = 2.89 and accuracy of 0.094
# Epoch 1, Overall loss = 1.85 and accuracy of 0.06
# Epoch 2, Overall loss = 1.8 and accuracy of 0.07
# Epoch 3, Overall loss = 1.74 and accuracy of 0.07
# Epoch 4, Overall loss = 1.68 and accuracy of 0.08
# Epoch 5, Overall loss = 1.63 and accuracy of 0.08
# Validation
# Epoch 1, Overall loss = 2.9 and accuracy of 0.077
#
# learning_rate 0.000330:
# 	accuracy: 0.077000	loss: 2.897674
#
# Training
# Iteration 0: with minibatch training loss = 2.73 and accuracy of 0.11
# Epoch 1, Overall loss = 1.74 and accuracy of 0.07
# Epoch 2, Overall loss = 1.7 and accuracy of 0.07
# Epoch 3, Overall loss = 1.66 and accuracy of 0.07
# Epoch 4, Overall loss = 1.62 and accuracy of 0.07
# Epoch 5, Overall loss = 1.58 and accuracy of 0.09
# Validation
# Epoch 1, Overall loss = 3.75 and accuracy of 0.098
#
# learning_rate 0.000347:
# 	accuracy: 0.098000	loss: 3.750175
#
# Training
# Iteration 0: with minibatch training loss = 2.6 and accuracy of 0.094
# Epoch 1, Overall loss = 1.67 and accuracy of 0.06
# Epoch 2, Overall loss = 1.51 and accuracy of 0.1
# Epoch 3, Overall loss = 1.4 and accuracy of 0.12
# Epoch 4, Overall loss = 1.31 and accuracy of 0.16
# Epoch 5, Overall loss = 1.22 and accuracy of 0.19
# Validation
# Epoch 1, Overall loss = 3.2 and accuracy of 0.116
#
# learning_rate 0.001383:
# 	accuracy: 0.116000	loss: 3.200986
#
# Training
# Iteration 0: with minibatch training loss = 2.99 and accuracy of 0.031
# Epoch 1, Overall loss = 1.91 and accuracy of 0.02
# Epoch 2, Overall loss = 1.69 and accuracy of 0.09
# Epoch 3, Overall loss = 1.52 and accuracy of 0.11
# Epoch 4, Overall loss = 1.38 and accuracy of 0.17
# Epoch 5, Overall loss = 1.28 and accuracy of 0.2
# Validation
# Epoch 1, Overall loss = 2.89 and accuracy of 0.073
#
# learning_rate 0.001472:
# 	accuracy: 0.073000	loss: 2.887522
#
# Training
# Iteration 0: with minibatch training loss = 2.84 and accuracy of 0.047
# Epoch 1, Overall loss = 1.82 and accuracy of 0.03
# Epoch 2, Overall loss = 1.74 and accuracy of 0.03
# Epoch 3, Overall loss = 1.66 and accuracy of 0.04
# Epoch 4, Overall loss = 1.59 and accuracy of 0.05
# Epoch 5, Overall loss = 1.53 and accuracy of 0.05
# Validation
# Epoch 1, Overall loss = 3.35 and accuracy of 0.092
#
# learning_rate 0.000927:
# 	accuracy: 0.092000	loss: 3.349002
#
# Training
# Iteration 0: with minibatch training loss = 2.57 and accuracy of 0.078
# Epoch 1, Overall loss = 1.65 and accuracy of 0.05
# Epoch 2, Overall loss = 1.63 and accuracy of 0.05
# Epoch 3, Overall loss = 1.61 and accuracy of 0.06
# Epoch 4, Overall loss = 1.6 and accuracy of 0.07
# Epoch 5, Overall loss = 1.58 and accuracy of 0.08
# Validation
# Epoch 1, Overall loss = 3.67 and accuracy of 0.1
#
# learning_rate 0.000143:
# 	accuracy: 0.100000	loss: 3.673414
#
# Training
# Iteration 0: with minibatch training loss = 2.65 and accuracy of 0.11
# Epoch 1, Overall loss = 1.7 and accuracy of 0.07
# Epoch 2, Overall loss = 1.64 and accuracy of 0.07
# Epoch 3, Overall loss = 1.58 and accuracy of 0.08
# Epoch 4, Overall loss = 1.53 and accuracy of 0.09
# Epoch 5, Overall loss = 1.47 and accuracy of 0.1
# Validation
# Epoch 1, Overall loss = 3.1 and accuracy of 0.12
#
# learning_rate 0.000517:
# 	accuracy: 0.120000	loss: 3.099332
#
# Training
# Iteration 0: with minibatch training loss = 2.82 and accuracy of 0.094
# Epoch 1, Overall loss = 1.8 and accuracy of 0.06
# Epoch 2, Overall loss = 1.78 and accuracy of 0.08
# Epoch 3, Overall loss = 1.75 and accuracy of 0.11
# Epoch 4, Overall loss = 1.73 and accuracy of 0.11
# Epoch 5, Overall loss = 1.7 and accuracy of 0.11
# Validation
# Epoch 1, Overall loss = 2.97 and accuracy of 0.074
#
# learning_rate 0.000198:
# 	accuracy: 0.074000	loss: 2.969708
#
# Training
# Iteration 0: with minibatch training loss = 2.85 and accuracy of 0.031
# Epoch 1, Overall loss = 1.83 and accuracy of 0.02
# Epoch 2, Overall loss = 1.81 and accuracy of 0.03
# Epoch 3, Overall loss = 1.79 and accuracy of 0.03
# Epoch 4, Overall loss = 1.77 and accuracy of 0.04
# Epoch 5, Overall loss = 1.74 and accuracy of 0.05
# Validation
# Epoch 1, Overall loss = 3.25 and accuracy of 0.084
#
# learning_rate 0.000150:
# 	accuracy: 0.084000	loss: 3.247165
#
# Training
# Iteration 0: with minibatch training loss = 2.63 and accuracy of 0.078
# Epoch 1, Overall loss = 1.69 and accuracy of 0.05
# Epoch 2, Overall loss = 1.59 and accuracy of 0.1
# Epoch 3, Overall loss = 1.49 and accuracy of 0.16
# Epoch 4, Overall loss = 1.4 and accuracy of 0.18
# Epoch 5, Overall loss = 1.31 and accuracy of 0.21
# Validation
# Epoch 1, Overall loss = 3.61 and accuracy of 0.066
#
# learning_rate 0.001412:
# 	accuracy: 0.066000	loss: 3.614231
#
# Training
# Iteration 0: with minibatch training loss = 3.07 and accuracy of 0.047
# Epoch 1, Overall loss = 1.96 and accuracy of 0.03
# Epoch 2, Overall loss = 1.88 and accuracy of 0.03
# Epoch 3, Overall loss = 1.79 and accuracy of 0.05
# Epoch 4, Overall loss = 1.7 and accuracy of 0.09
# Epoch 5, Overall loss = 1.62 and accuracy of 0.1
# Validation
# Epoch 1, Overall loss = 3.13 and accuracy of 0.109
#
# learning_rate 0.000548:
# 	accuracy: 0.109000	loss: 3.127362
#
# Training
# Iteration 0: with minibatch training loss = 2.74 and accuracy of 0.14
# Epoch 1, Overall loss = 1.75 and accuracy of 0.09
# Epoch 2, Overall loss = 1.43 and accuracy of 0.16
# Epoch 3, Overall loss = 1.27 and accuracy of 0.21
# Epoch 4, Overall loss = 1.17 and accuracy of 0.27
# Epoch 5, Overall loss = 1.08 and accuracy of 0.32
# Validation
# Epoch 1, Overall loss = 2.93 and accuracy of 0.119
#
# learning_rate 0.004462:
# 	accuracy: 0.119000	loss: 2.927951
#
# Training
# Iteration 0: with minibatch training loss = 2.53 and accuracy of 0.16
# Epoch 1, Overall loss = 1.62 and accuracy of 0.1
# Epoch 2, Overall loss = 1.6 and accuracy of 0.11
# Epoch 3, Overall loss = 1.58 and accuracy of 0.11
# Epoch 4, Overall loss = 1.55 and accuracy of 0.11
# Epoch 5, Overall loss = 1.53 and accuracy of 0.11
# Validation
# Epoch 1, Overall loss = 2.57 and accuracy of 0.098
#
# learning_rate 0.000140:
# 	accuracy: 0.098000	loss: 2.568816
#
# Training
# Iteration 0: with minibatch training loss = 2.7 and accuracy of 0.12
# Epoch 1, Overall loss = 1.73 and accuracy of 0.08
# Epoch 2, Overall loss = 1.42 and accuracy of 0.14
# Epoch 3, Overall loss = 1.24 and accuracy of 0.2
# Epoch 4, Overall loss = 1.1 and accuracy of 0.26
# Epoch 5, Overall loss = 0.981 and accuracy of 0.33
# Validation
# Epoch 1, Overall loss = 4.63 and accuracy of 0.1
#
# learning_rate 0.004649:
# 	accuracy: 0.100000	loss: 4.628667
#
# Training
# Iteration 0: with minibatch training loss = 2.82 and accuracy of 0.12
# Epoch 1, Overall loss = 1.8 and accuracy of 0.08
# Epoch 2, Overall loss = 1.24 and accuracy of 0.24
# Epoch 3, Overall loss = 0.989 and accuracy of 0.34
# Epoch 4, Overall loss = 0.802 and accuracy of 0.45
# Epoch 5, Overall loss = 0.767 and accuracy of 0.51
# Validation
# Epoch 1, Overall loss = 2.91 and accuracy of 0.103
#
# learning_rate 0.007848:
# 	accuracy: 0.103000	loss: 2.909166
#
# Training
# Iteration 0: with minibatch training loss = 2.69 and accuracy of 0.12
# Epoch 1, Overall loss = 1.72 and accuracy of 0.08
# Epoch 2, Overall loss = 1.4 and accuracy of 0.16
# Epoch 3, Overall loss = 1.17 and accuracy of 0.22
# Epoch 4, Overall loss = 0.982 and accuracy of 0.31
# Epoch 5, Overall loss = 0.846 and accuracy of 0.51
# Validation
# Epoch 1, Overall loss = 2.95 and accuracy of 0.111
#
# learning_rate 0.004898:
# 	accuracy: 0.111000	loss: 2.945100
#
# Training
# Iteration 0: with minibatch training loss = 2.79 and accuracy of 0.12
# Epoch 1, Overall loss = 1.78 and accuracy of 0.08
# Epoch 2, Overall loss = 1.31 and accuracy of 0.19
# Epoch 3, Overall loss = 1.1 and accuracy of 0.26
# Epoch 4, Overall loss = 0.954 and accuracy of 0.35
# Epoch 5, Overall loss = 0.848 and accuracy of 0.43
# Validation
# Epoch 1, Overall loss = 3.84 and accuracy of 0.101
#
# learning_rate 0.004494:
# 	accuracy: 0.101000	loss: 3.839433
#
# Training
# Iteration 0: with minibatch training loss = 2.79 and accuracy of 0.078
# Epoch 1, Overall loss = 1.79 and accuracy of 0.05
# Epoch 2, Overall loss = 1.4 and accuracy of 0.13
# Epoch 3, Overall loss = 1.19 and accuracy of 0.22
# Epoch 4, Overall loss = 1.03 and accuracy of 0.31
# Epoch 5, Overall loss = 0.887 and accuracy of 0.38
# Validation
# Epoch 1, Overall loss = 2.56 and accuracy of 0.101
#
# learning_rate 0.003781:
# 	accuracy: 0.101000	loss: 2.563632
#
# Training
# Iteration 0: with minibatch training loss = 2.41 and accuracy of 0.11
# Epoch 1, Overall loss = 1.54 and accuracy of 0.07
# Epoch 2, Overall loss = 1.28 and accuracy of 0.17
# Epoch 3, Overall loss = 1.12 and accuracy of 0.22
# Epoch 4, Overall loss = 0.995 and accuracy of 0.32
# Epoch 5, Overall loss = 0.893 and accuracy of 0.4
# Validation
# Epoch 1, Overall loss = 4.03 and accuracy of 0.116
#
# learning_rate 0.002943:
# 	accuracy: 0.116000	loss: 4.033549
#
# Training
# Iteration 0: with minibatch training loss = 2.51 and accuracy of 0.16
# Epoch 1, Overall loss = 1.61 and accuracy of 0.1
# Epoch 2, Overall loss = 1.59 and accuracy of 0.1
# Epoch 3, Overall loss = 1.58 and accuracy of 0.1
# Epoch 4, Overall loss = 1.56 and accuracy of 0.1
# Epoch 5, Overall loss = 1.54 and accuracy of 0.1
# Validation
# Epoch 1, Overall loss = 2.97 and accuracy of 0.088
#
# learning_rate 0.000162:
# 	accuracy: 0.088000	loss: 2.968597
#
# Training
# Iteration 0: with minibatch training loss = 2.54 and accuracy of 0.12
# Epoch 1, Overall loss = 1.63 and accuracy of 0.08
# Epoch 2, Overall loss = 1.19 and accuracy of 0.21
# Epoch 3, Overall loss = 0.983 and accuracy of 0.28
# Epoch 4, Overall loss = 0.901 and accuracy of 0.39
# Epoch 5, Overall loss = 0.883 and accuracy of 0.46
# Validation
# Epoch 1, Overall loss = 4.34 and accuracy of 0.086
#
# learning_rate 0.006939:
# 	accuracy: 0.086000	loss: 4.337107
#
# Training
# Iteration 0: with minibatch training loss = 2.75 and accuracy of 0.062
# Epoch 1, Overall loss = 1.76 and accuracy of 0.04
# Epoch 2, Overall loss = 1.22 and accuracy of 0.27
# Epoch 3, Overall loss = 0.94 and accuracy of 0.37
# Epoch 4, Overall loss = 0.799 and accuracy of 0.43
# Epoch 5, Overall loss = 0.85 and accuracy of 0.38
# Validation
# Epoch 1, Overall loss = 3.4 and accuracy of 0.133
#
# learning_rate 0.007311:
# 	accuracy: 0.133000	loss: 3.403517
#
# Training
# Iteration 0: with minibatch training loss = 2.45 and accuracy of 0.14
# Epoch 1, Overall loss = 1.57 and accuracy of 0.09
# Epoch 2, Overall loss = 1.32 and accuracy of 0.14
# Epoch 3, Overall loss = 1.16 and accuracy of 0.25
# Epoch 4, Overall loss = 1.04 and accuracy of 0.32
# Epoch 5, Overall loss = 0.952 and accuracy of 0.4
# Validation
# Epoch 1, Overall loss = 3.57 and accuracy of 0.099
#
# learning_rate 0.002516:
# 	accuracy: 0.099000	loss: 3.571423
#
# Training
# Iteration 0: with minibatch training loss = 2.69 and accuracy of 0.16
# Epoch 1, Overall loss = 1.72 and accuracy of 0.1
# Epoch 2, Overall loss = 1.69 and accuracy of 0.1
# Epoch 3, Overall loss = 1.65 and accuracy of 0.11
# Epoch 4, Overall loss = 1.61 and accuracy of 0.11
# Epoch 5, Overall loss = 1.58 and accuracy of 0.11
# Validation
# Epoch 1, Overall loss = 3.36 and accuracy of 0.116
#
# learning_rate 0.000437:
# 	accuracy: 0.116000	loss: 3.360725
#
# Training
# Iteration 0: with minibatch training loss = 2.71 and accuracy of 0.11
# Epoch 1, Overall loss = 1.73 and accuracy of 0.07
# Epoch 2, Overall loss = 1.72 and accuracy of 0.07
# Epoch 3, Overall loss = 1.71 and accuracy of 0.08
# Epoch 4, Overall loss = 1.7 and accuracy of 0.08
# Epoch 5, Overall loss = 1.68 and accuracy of 0.08
# Validation
# Epoch 1, Overall loss = 3.04 and accuracy of 0.085
#
# learning_rate 0.000127:
# 	accuracy: 0.085000	loss: 3.042635
#
# Training
# Iteration 0: with minibatch training loss = 2.82 and accuracy of 0.11
# Epoch 1, Overall loss = 1.8 and accuracy of 0.07
# Epoch 2, Overall loss = 1.56 and accuracy of 0.11
# Epoch 3, Overall loss = 1.37 and accuracy of 0.15
# Epoch 4, Overall loss = 1.21 and accuracy of 0.25
# Epoch 5, Overall loss = 1.07 and accuracy of 0.3
# Validation
# Epoch 1, Overall loss = 2.56 and accuracy of 0.116
#
# learning_rate 0.002360:
# 	accuracy: 0.116000	loss: 2.562589
#
# Training
# Iteration 0: with minibatch training loss = 2.95 and accuracy of 0.12
# Epoch 1, Overall loss = 1.89 and accuracy of 0.08
# Epoch 2, Overall loss = 1.67 and accuracy of 0.12
# Epoch 3, Overall loss = 1.48 and accuracy of 0.16
# Epoch 4, Overall loss = 1.32 and accuracy of 0.22
# Epoch 5, Overall loss = 1.2 and accuracy of 0.25
# Validation
# Epoch 1, Overall loss = 4.05 and accuracy of 0.099
#
# learning_rate 0.002663:
# 	accuracy: 0.099000	loss: 4.053679
#
# Training
# Iteration 0: with minibatch training loss = 2.7 and accuracy of 0.078
# Epoch 1, Overall loss = 1.73 and accuracy of 0.05
# Epoch 2, Overall loss = 1.48 and accuracy of 0.11
# Epoch 3, Overall loss = 1.3 and accuracy of 0.17
# Epoch 4, Overall loss = 1.17 and accuracy of 0.24
# Epoch 5, Overall loss = 1.06 and accuracy of 0.32
# Validation
# Epoch 1, Overall loss = 2.52 and accuracy of 0.109
#
# learning_rate 0.002156:
# 	accuracy: 0.109000	loss: 2.520331
#
# Training
# Iteration 0: with minibatch training loss = 2.75 and accuracy of 0.062
# Epoch 1, Overall loss = 1.76 and accuracy of 0.04
# Epoch 2, Overall loss = 1.44 and accuracy of 0.17
# Epoch 3, Overall loss = 1.26 and accuracy of 0.21
# Epoch 4, Overall loss = 1.14 and accuracy of 0.27
# Epoch 5, Overall loss = 1.03 and accuracy of 0.35
# Validation
# Epoch 1, Overall loss = 2.71 and accuracy of 0.126
#
# learning_rate 0.003096:
# 	accuracy: 0.126000	loss: 2.707968
#
# Training
# Iteration 0: with minibatch training loss = 2.67 and accuracy of 0.14
# Epoch 1, Overall loss = 1.71 and accuracy of 0.09
# Epoch 2, Overall loss = 1.64 and accuracy of 0.09
# Epoch 3, Overall loss = 1.57 and accuracy of 0.1
# Epoch 4, Overall loss = 1.51 and accuracy of 0.11
# Epoch 5, Overall loss = 1.44 and accuracy of 0.15
# Validation
# Epoch 1, Overall loss = 3.26 and accuracy of 0.12
#
# learning_rate 0.000713:
# 	accuracy: 0.120000	loss: 3.258402
#
# ('best_accuracy: %f\nlearning_rate:%f', 0.15, 0.0007126305509628963)

# %%
run_model(sess,y_out,mean_loss,X,y,is_training,X_train[:100],y_train[:100],
          epochs=1, batch_size=64)
# Out:
# <tensorflow.python.framework.ops.Graph object at 0x17e0033d0>
# <tensorflow.python.framework.ops.Graph object at 0x122730210>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-753b539a64f9> in <module>()
#       1 run_model(sess,y_out,mean_loss,y,X_train[:100],y_train[:100],
# ----> 2           epochs=1, batch_size=64)
#
# <ipython-input-4-9baee0642d3d> in run_model(session, predict, loss_val, y, Xd, yd, epochs, batch_size, print_every, training, plot_losses)
#       5     print(y.graph)
#       6     print(predict.graph)
# ----> 7     correct_prediction = tf.equal(tf.argmax(predict,1), y)
#       8     accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
#       9
#
# /Users/jeong/Dev/python/projects/cs231/assignments/assignment2/.env/lib/python2.7/site-packages/tensorflow/python/ops/gen_math_ops.pyc in equal(x, y, name)
#    2527   if _ctx is None or not _ctx._eager_context.is_eager:
#    2528     _, _, _op = _op_def_lib._apply_op_helper(
# -> 2529         "Equal", x=x, y=y, name=name)
#    2530     _result = _op.outputs[:]
#    2531     _inputs_flat = _op.inputs
#
# /Users/jeong/Dev/python/projects/cs231/assignments/assignment2/.env/lib/python2.7/site-packages/tensorflow/python/framework/op_def_library.pyc in _apply_op_helper(self, op_type_name, name, **keywords)
#     348       # Need to flatten all the arguments into a list.
#     349       # pylint: disable=protected-access
# --> 350       g = ops._get_graph_from_inputs(_Flatten(keywords.values()))
#     351       # pylint: enable=protected-access
#     352     except AssertionError as e:
#
# /Users/jeong/Dev/python/projects/cs231/assignments/assignment2/.env/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in _get_graph_from_inputs(op_input_list, graph)
#    5635         graph = graph_element.graph
#    5636       elif original_graph_element is not None:
# -> 5637         _assert_same_graph(original_graph_element, graph_element)
#    5638       elif graph_element.graph is not graph:
#    5639         raise ValueError("%s is not from the passed-in graph." % graph_element)
#
# /Users/jeong/Dev/python/projects/cs231/assignments/assignment2/.env/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in _assert_same_graph(original_item, item)
#    5571   if original_item.graph is not item.graph:
#    5572     raise ValueError("%s must be from the same graph as %s." % (item,
# -> 5573                                                                 original_item))
#    5574
#    5575
#
# ValueError: Tensor("ArgMax_1:0", shape=(?,), dtype=int64) must be from the same graph as Tensor("Placeholder_1:0", shape=(?,), dtype=int64).

# %%
# Test your model here, and make sure 
# the output of this cell is the accuracy
# of your best model on the training and val sets
# We're looking for >= 70% accuracy on Validation
print('Training')
run_model(sess,y_out,mean_loss,X,y,is_training,X_train,y_train,1,64)
print('Validation')
run_model(sess,y_out,mean_loss,X,y,is_training,X_val,y_val,1,64)

# %% [markdown]
# ### Describe what you did here
# In this cell you should also write an explanation of what you did, any additional features that you implemented, and any visualizations or graphs that you make in the process of training and evaluating your network

# %% [markdown]
# _Tell us here_

# %% [markdown]
# ### Test Set - Do this only once
# Now that we've gotten a result that we're happy with, we test our final model on the test set. This would be the score we would achieve on a competition. Think about how this compares to your validation set accuracy.

# %%
print('Test')
run_model(sess,y_out,mean_loss,X,y,is_training,X_test,y_test,1,64)

# %% [markdown]
# ## Going further with TensorFlow
#
# The next assignment will make heavy use of TensorFlow. You might also find it useful for your projects.

# %% [markdown]
# # Extra Credit Description
# If you implement any additional features for extra credit, clearly describe them here with pointers to any code in this or other files if applicable.
